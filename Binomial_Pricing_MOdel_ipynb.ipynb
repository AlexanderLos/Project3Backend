# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexanderLos/Project3Backend/blob/main/Binomial_Pricing_MOdel_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Binomial Option Pricing
# Pricing model with Python <br>
# n = total steps (or periods) <br>
# i = number of up moves/positive events <br>
# ![image.png](data:image/png;base64,...)= number of paths where the stock moves up i times
# (i )

# %% [markdown]
# ###Binomial coefficient formula

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import math

def combos(n, i):
  return math.factorial(n)/(math.factorial(n-i)*math.factorial(i))


for i in range(5):
  print(combos(4, i))
# Out:
# 1.0
# 4.0
# 6.0
# 4.0
# 1.0
